# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_csv('../Resources/cleaned_data.csv')

df.head(10)
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS              67               SDN
# 1                 NY        PAS              51              SUBN
# 2                 NJ        PAS              63               SDN
# 3                 NJ        PAS              63               SDN
# 4                 NY        PAS              67              SUBN
# 5                 NY        PAS              98              SUBN
# 6                 NJ        PAS              10              SUBN
# 7                 PA        PAS              10              SUBN
# 8                 FL        PAS              51              SUBN
# 9                 NY        PAS              63              SUBN
#
#   Vehicle Make  Vehicle Expiration Date Violation Time Vehicle Color  \
# 0        TOYOT                 20221210          1037A           BLK
# 1         JEEP                 20220908          1045A          GRAY
# ...

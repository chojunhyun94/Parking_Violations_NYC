# %%
import pandas as pd

# %%
df = pd.read_csv('../Final Project/Resources/cleaned_data.csv')

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS              67               SDN
# 1                 NY        PAS              51              SUBN
# 2                 NY        PAS              67              SUBN
# 3                 NY        PAS              98              SUBN
# 4                 FL        PAS              51              SUBN
# 5                 NY        PAS              63              SUBN
# 6                 NY        PAS              45               SDN
# 7                 NY        OMS              14               SDN
# 8                 NY        PAS              20              SUBN
# 9                 NY        PAS              27               SDN
#
#   Vehicle Make  Vehicle Expiration Date Violation Time Vehicle Color  \
# 0        TOYOT                 20221210          1037A           BLK
# 1         JEEP                 20220908          1045A          GRAY
# 2        TOYOT                 20230120          1205P         WHITE
# 3        NISSA                 20230121          0535P           BLK
# 4        SUBAR                 20230713          0320P          GRAY
# 5        CHEVR                 20230103          1102A           WHT
# 6        NISSA                 20240321          0606P           BLK
# 7        TOYOT                 20220930          1250P         BLACK
# 8        HONDA                 20221205          1031A           RED
# 9        NISSA                 20220716          0607P         BLACK
#
#    Vehicle Year
# 0          2004
# 1          2017
# 2          2021
# 3          2002
# 4          2005
# 5          2010
# 6          2002
# 7          2022
# 8          2005
# 9          2022

# %%
replace =  df.mask(lambda x: x == 'BLACK', other= 'BLK')
replace.head(10)
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS              67               SDN
# 1                 NY        PAS              51              SUBN
# 2                 NY        PAS              67              SUBN
# 3                 NY        PAS              98              SUBN
# 4                 FL        PAS              51              SUBN
# 5                 NY        PAS              63              SUBN
# 6                 NY        PAS              45               SDN
# 7                 NY        OMS              14               SDN
# 8                 NY        PAS              20              SUBN
# 9                 NY        PAS              27               SDN
#
#   Vehicle Make  Vehicle Expiration Date Violation Time Vehicle Color  \
# 0        TOYOT                 20221210          1037A           BLK
# 1         JEEP                 20220908          1045A          GRAY
# 2        TOYOT                 20230120          1205P         WHITE
# 3        NISSA                 20230121          0535P           BLK
# 4        SUBAR                 20230713          0320P          GRAY
# 5        CHEVR                 20230103          1102A           WHT
# 6        NISSA                 20240321          0606P           BLK
# 7        TOYOT                 20220930          1250P           BLK
# 8        HONDA                 20221205          1031A           RED
# 9        NISSA                 20220716          0607P           BLK
#
#    Vehicle Year
# 0          2004
# 1          2017
# 2          2021
# 3          2002
# 4          2005
# 5          2010
# 6          2002
# 7          2022
# 8          2005
# 9          2022

# %%
replace2 =  df.mask(lambda x: x == 'WHITE', other= 'WHT')
replace2.head(10)
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS              67               SDN
# 1                 NY        PAS              51              SUBN
# 2                 NY        PAS              67              SUBN
# 3                 NY        PAS              98              SUBN
# 4                 FL        PAS              51              SUBN
# 5                 NY        PAS              63              SUBN
# 6                 NY        PAS              45               SDN
# 7                 NY        OMS              14               SDN
# 8                 NY        PAS              20              SUBN
# 9                 NY        PAS              27               SDN
#
#   Vehicle Make  Vehicle Expiration Date Violation Time Vehicle Color  \
# 0        TOYOT                 20221210          1037A           BLK
# 1         JEEP                 20220908          1045A          GRAY
# 2        TOYOT                 20230120          1205P           WHT
# 3        NISSA                 20230121          0535P           BLK
# 4        SUBAR                 20230713          0320P          GRAY
# 5        CHEVR                 20230103          1102A           WHT
# 6        NISSA                 20240321          0606P           BLK
# 7        TOYOT                 20220930          1250P         BLACK
# 8        HONDA                 20221205          1031A           RED
# 9        NISSA                 20220716          0607P         BLACK
#
#    Vehicle Year
# 0          2004
# 1          2017
# 2          2021
# 3          2002
# 4          2005
# 5          2010
# 6          2002
# 7          2022
# 8          2005
# 9          2022

# %%
car_colors = df.loc[df['Vehicle Color'].isin(["BLACK", "WHITE","BLUE", "GREY", "SILVE","ORANG","PURPL","BEIGE","GREEN","PINK"])]
car_colors.head(10)
# Out:
#    Registration State Plate Type  Violation Code Vehicle Body Type  \
# 2                  NY        PAS              67              SUBN
# 7                  NY        OMS              14               SDN
# 9                  NY        PAS              27               SDN
# 10                 NY        PAS              20              SUBN
# 12                 NY        PAS              20              SUBN
# 14                 NY        PAS              68               SDN
# 15                 NY        PAS              20               SDN
# 16                 NY        PAS              27               SDN
# 17                 NY        PAS              14              SUBN
# 19                 NY        PAS              68              SUBN
#
#    Vehicle Make  Vehicle Expiration Date Violation Time Vehicle Color  \
# 2         TOYOT                 20230120          1205P         WHITE
# 7         TOYOT                 20220930          1250P         BLACK
# 9         NISSA                 20220716          0607P         BLACK
# 10        ME/BE                 20230902          0712P         WHITE
# 12        ME/BE                 20240303          0156P         WHITE
# 14        CHEVR                 20221018          0626P         SILVE
# 15        CHEVR                 20221029          0841P         SILVE
# 16        VOLKS                 20231007          0613P         BLACK
# 17        ACURA                 20220909          0940A         WHITE
# 19        HONDA                 20221011          1221P          BLUE
#
#     Vehicle Year
# 2           2021
# 7           2022
# 9           2022
# 10          2021
# 12          2019
# 14          2015
# 15          2011
# 16          2018
# 17          2020
# 19          2020

# %%
car_colors['Vehicle Color'].unique()
# Out:
# array(['WHITE', 'BLACK', 'SILVE', 'BLUE', 'GREY', 'ORANG', 'PURPL',
#        'BEIGE', 'GREEN', 'PINK'], dtype=object)

# %%
colors = {
    'WHITE': 1,
    'BLACK': 2,
    'RED': 3,
    'GREY': 4,
    'ORANG': 5,
    'PURPL': 6,
    'BEIGE': 7,
    'GREEN': 8,
    'PINK': 9,
    'BLUE': 10,
    
}

# %%
df['Vehicle Color'] = df['Vehicle Color'].apply(lambda x: colors[x] if (x in colors) else 9)
car_colors.head(10)
# Out:
#    Registration State Plate Type  Violation Code Vehicle Body Type  \
# 2                  NY        PAS              67              SUBN
# 7                  NY        OMS              14               SDN
# 9                  NY        PAS              27               SDN
# 10                 NY        PAS              20              SUBN
# 12                 NY        PAS              20              SUBN
# 14                 NY        PAS              68               SDN
# 15                 NY        PAS              20               SDN
# 16                 NY        PAS              27               SDN
# 17                 NY        PAS              14              SUBN
# 19                 NY        PAS              68              SUBN
#
#    Vehicle Make  Vehicle Expiration Date Violation Time  Vehicle Color  \
# 2         TOYOT                 20230120          1205P              1
# 7         TOYOT                 20220930          1250P              2
# 9         NISSA                 20220716          0607P              2
# 10        ME/BE                 20230902          0712P              1
# 12        ME/BE                 20240303          0156P              1
# 14        CHEVR                 20221018          0626P              9
# 15        CHEVR                 20221029          0841P              9
# 16        VOLKS                 20231007          0613P              2
# 17        ACURA                 20220909          0940A              1
# 19        HONDA                 20221011          1221P             10
#
#     Vehicle Year
# 2           2021
# 7           2022
# 9           2022
# 10          2021
# 12          2019
# 14          2015
# 15          2011
# 16          2018
# 17          2020
# 19          2020

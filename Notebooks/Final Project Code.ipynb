# %%
import pandas as pd

# %%
df = pd.read_csv('../Resources/cleaned_data.csv')

# %%
pd.set_option('display.max_columns', None)
df.count()
# Out:
# Registration State    7659315
# Plate Type            7659315
# Violation Code        7659315
# Vehicle Body Type     7659315
# Vehicle Make          7659315
# Violation Time        7659315
# Vehicle Color         7659315
# Vehicle Year          7659315
# dtype: int64

# %%
color_conversion = {
    'RED': ['RD', 'RED', 'R'],
    'BLK': ['BLK', 'BLACK', 'BK']
}
for x in color_conversion:
    print(x)
# Out:
# RED
# BLK

# %%
df['Vehicle Color'] =

# %%
for x in color_conversion:
    replace =  df.mask(lambda x: x is in color_conversion[x], other= x)
replace.count()
# Out:
# Registration State    7659315
# Plate Type            7659315
# Violation Code        7659315
# Vehicle Body Type     7659315
# Vehicle Make          7659315
# Violation Time        7659315
# Vehicle Color         7659315
# Vehicle Year          7659315
# dtype: int64

# %%
replace2.head(10)
# Out:
#   Registration State Plate Type  Violation Code Vehicle Body Type  \
# 0                 NY        PAS              67               SDN
# 1                 NY        PAS              51              SUBN
# 2                 NY        PAS              67              SUBN
# 3                 NY        PAS              98              SUBN
# 4                 FL        PAS              51              SUBN
# 5                 NY        PAS              63              SUBN
# 6                 NY        PAS              45               SDN
# 7                 NY        OMS              14               SDN
# 8                 NY        PAS              20              SUBN
# 9                 NY        PAS              27               SDN
#
#   Vehicle Make Violation Time Vehicle Color  Vehicle Year
# 0        TOYOT          1037A           BLK          2004
# 1         JEEP          1045A          GRAY          2017
# 2        TOYOT          1205P           WHT          2021
# ...

# %%
for x in replace4['Vehicle Color'].unique():
    print(x)
# Out:
# BLK
# GY
# WHT
# RD
# GL
# SILVE
# BLUE
# GREY
# BL
# TAN
# WH
# GRY
# BLU
# BRO
# ORANG
# PURPL
# SLV
# SIL
# WT
# ORG
# SUILV
# BEIGE
# BK
# GR
# GOLD
# NAVY
# SILV
# R
# G
# WHI
# BUR
# BROW
# B
# BROWN
# SI
# BKL
# W
# SL
# YLLW
# GREEN
# GRV
# GRN
# GLD
# SV
# SLVR
# BURG
# SW
# TN
# WHTE
# BN
# GRAN
# BR
# BUG
# WHIT
# PINK
# GARY
# BLC
# GN
# BRW
# M
# Gray
# PUR
# PURP
# BLCK
# BRN
# WTE
# GD
# GRA
# T
# BLA
# SILVR
# BW
# BLAAC
# GRED
# BLACJ
# YEL
# MAROO
# .
# SN
# YELLO
# YE
# OR
# BKUE
# GKD
# LTGY
# YELL
# OLIV
# BG
# WI
# BLAC
# YW
# TEAL
# BLAK
# GLN
# BWN
# GRE
# SIVR
# BIGE
# BURGU
# ON
# SILIV
# MN
# PR
# BRWN
# PK
# BURGA
# BLE
# SLIVE
# SILVA
# MR
# GREN
# DK/GY
# BLGY
# LT/GR
# DKRD
# DKGY
# LTBK
# SIV
# LT/GY
# BL/BK
# DK/BL
# WHTN
# DK/PR
# DKGR
# WHBR
# DKBL
# WH/BK
# NOCL
# LT/BL
# DKTN
# LTBL
# WHGL
# BKGY
# LTGR
# BKWH
# GLGY
# WH/BL
# GYGR
# WHGY
# SLK
# WHBL
# GYBK
# RDBK
# BKBL
# Black
# BKGL
# WHBK
# LTBR
# DKMR
# GYBL
# GYTN
# GYGY
# UNKNO
# LTGL
# ...

# %%
car_colors = df.loc[df['Vehicle Color'].isin(["BLACK", "WHITE","BLUE", "GREY", "SILVE","ORANG","PURPL","BEIGE","GREEN","PINK"])]
car_colors.head(10)
# Out:
#    Registration State Plate Type  Violation Code Vehicle Body Type  \
# 2                  NY        PAS              67              SUBN
# 7                  NY        OMS              14               SDN
# 9                  NY        PAS              27               SDN
# 10                 NY        PAS              20              SUBN
# 12                 NY        PAS              20              SUBN
# 14                 NY        PAS              68               SDN
# 15                 NY        PAS              20               SDN
# 16                 NY        PAS              27               SDN
# 17                 NY        PAS              14              SUBN
# 19                 NY        PAS              68              SUBN
#
#    Vehicle Make Violation Time Vehicle Color  Vehicle Year
# 2         TOYOT          1205P         WHITE          2021
# 7         TOYOT          1250P         BLACK          2022
# ...

# %%
car_colors['Vehicle Color'].unique()
# Out:
# array(['WHITE', 'BLACK', 'SILVE', 'BLUE', 'GREY', 'ORANG', 'PURPL',
#        'BEIGE', 'GREEN', 'PINK'], dtype=object)

# %%
colors = {
    'WHITE': 1,
    'BLACK': 2,
    'RED': 3,
    'GREY': 4,
    'ORANG': 5,
    'PURPL': 6,
    'BEIGE': 7,
    'GREEN': 8,
    'PINK': 9,
    'BLUE': 10,
    
}

# %%
df['Vehicle Color'] = df['Vehicle Color'].apply(lambda x: colors[x] if (x in colors) else 11)
car_colors.head(10)
# Out:
#    Registration State Plate Type  Violation Code Vehicle Body Type  \
# 2                  NY        PAS              67              SUBN
# 7                  NY        OMS              14               SDN
# 9                  NY        PAS              27               SDN
# 10                 NY        PAS              20              SUBN
# 12                 NY        PAS              20              SUBN
# 14                 NY        PAS              68               SDN
# 15                 NY        PAS              20               SDN
# 16                 NY        PAS              27               SDN
# 17                 NY        PAS              14              SUBN
# 19                 NY        PAS              68              SUBN
#
#    Vehicle Make Violation Time Vehicle Color  Vehicle Year
# 2         TOYOT          1205P         WHITE          2021
# 7         TOYOT          1250P         BLACK          2022
# ...

# %%
df['Vehicle Color'].count()
# Out:
# 7659315
